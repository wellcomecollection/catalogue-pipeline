# %%
# %env AWS_PROFILE=platform-developer
# Out:
# env: AWS_PROFILE=platform-developer

# %%
from utils.aws import get_secret
import elasticsearch

import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

ES_ENDPOINT = "https://semantic-playground-b28f61.es.eu-west-1.aws.elastic.cloud:443"
ES_API_KEY = get_secret("agnes/elasticsearch/semantic-playground")
ES_CLIENT = elasticsearch.Elasticsearch(ES_ENDPOINT, api_key=ES_API_KEY, request_timeout=120)

# %%
# Pretty print utils
import re

BOLD = "\033[1m"
RESET = "\033[0m"
RESET_COLOR = "\033[39m"

def get_work_url(work_id: str):
    return f"https://wellcomecollection.org/works/{work_id}"

def highlight_terms(text, terms, color="\033[92m"):
    for term in terms:
        pattern = re.compile(re.escape(term), re.IGNORECASE)
        text = pattern.sub(lambda m: f"{color}{m.group(0)}{RESET_COLOR}", text)

    return text

def print_bold(text: str):
    print(f"{BOLD}{text}{RESET}")

# %%
def get_full_query(query: str):
    return {
        "bool": {
            "should": [
                {
                    "multi_match": {
                        "_name": "text_strict",
                        "query": f"{query}",
                        "fields": [
                            "query.title.*^5",
                            "query.title.cased^10",
                            "query.contributors.agent.label^10",
                            "query.subjects.concepts.label^10",
                            "query.genres.concepts.label^10",
                            "query.production.label.*^10",
                            "query.partOf.title.*^10",
                            "query.alternativeTitles.*",
                            "query.description.*",
                            "query.edition",
                            "query.languages.label",
                            "query.lettering.*",
                            "query.notes.contents.*",
                            "query.physicalDescription.*"
                        ],
                        "type": "cross_fields",
                        "tie_breaker": 0.4,
                        "minimum_should_match": "3<-20%",
                        "operator": "Or"
                    }
                },
                {
                    "match_phrase_prefix": {
                        "query.title.normalized_whole_phrase": {
                            "_name": "title_prefix",
                            "query": f"{query}",
                            "boost": 50
                        }
                    }
                },
                {
                    "multi_match": {
                        "_name": "ids_lax",
                        "query": f"{query}",
                        "analyzer": "lowercase_whitespace_tokens",
                        "fields": [
                            "query.id^5",
                            "query.sourceIdentifier.value^5",
                            "query.identifiers.value",
                            "query.items.id",
                            "query.items.identifiers.value",
                            "query.images.id",
                            "query.images.identifiers.value",
                            "query.referenceNumber*"
                        ],
                        "type": "cross_fields",
                        "boost": 100,
                        "operator": "OR",
                        "minimum_should_match": 1
                    }
                },
                {
                    "multi_match": {
                        "_name": "ids_with_path_lax",
                        "query": f"{query}",
                        "analyzer": "lowercase_whitespace_tokens",
                        "fields": ["query.items.shelfmark*", "query.collectionPath*"],
                        "type": "cross_fields",
                        "boost": 50,
                        "operator": "OR",
                        "minimum_should_match": 1
                    }
                },
                {
                    "bool": {
                        "must": [
                            {
                                "multi_match": {
                                    "_name": "text_lax",
                                    "query": f"{query}",
                                    "fields": [
                                        "query.title.*^5",
                                        "query.title.cased^10",
                                        "query.contributors.agent.label^10",
                                        "query.subjects.concepts.label^10",
                                        "query.genres.concepts.label^10",
                                        "query.production.label.*^10",
                                        "query.partOf.title.*^10",
                                        "query.alternativeTitles.*",
                                        "query.description.*",
                                        "query.edition",
                                        "query.languages.label",
                                        "query.lettering.*",
                                        "query.notes.contents.*",
                                        "query.physicalDescription.*"
                                    ],
                                    "type": "cross_fields",
                                    "tie_breaker": 0.4,
                                    "minimum_should_match": 1,
                                    "operator": "OR"
                                }
                            }
                        ],
                        "filter": [
                            {
                                "multi_match": {
                                    "query": f"{query}",
                                    "analyzer": "lowercase_whitespace_tokens",
                                    "fields": [
                                        "query.id^5",
                                        "query.sourceIdentifier.value^5",
                                        "query.referenceNumber*^5",
                                        "query.identifiers.value",
                                        "query.items.id",
                                        "query.items.identifiers.value",
                                        "query.items.shelfmark*",
                                        "query.images.id",
                                        "query.images.identifiers.value",
                                        "query.collectionPath*"
                                    ],
                                    "type": "cross_fields",
                                    "operator": "OR",
                                    "minimum_should_match": 1
                                }
                            }
                        ]
                    }
                }
            ]
        }
    }


def get_basic_query(query: str, fields: list[str]) -> dict:
    return {
        "bool": {
            "should": [
                {"match": {field: {"query": query}}}
                for field in fields
            ]
        }
    }
    

def get_basic_knn_query(query: str, fields: list[str]) -> dict:
    search_query = {
        "bool": {
          "should": []
        }
    }

    for field in fields:
        search_query["bool"]["should"].append({
              "knn": {
                "field": field,
                "k": 50,
                "num_candidates": 500,
                # "boost": 1.0,
                "query_vector_builder": {
                  "text_embedding": {
                    "model_id": "amazon-bedrock-titan-embeddings",
                    "model_text": query
                  }
                }
              }
            }
        )
    
    return search_query

# %%
SIZE = 100
PRINT_LIMIT = 10
INDEXES = {
    "elser_eis": "works-elser-title-description",
    "bedrock_titan": "works-titan-title-description",
    "non_semantic": "works-non-semantic",
    "production": "works-non-semantic"
}
COMPARISON_LABELS = {
    "elser_eis": "ELSER",
    "bedrock_titan": "Titan",
    "non_semantic": "Control",
    "production": "Production"
}
INDEX_COLORS = {
    "elser_eis": "\033[34m",
    "bedrock_titan": "\033[91m",
    "non_semantic": "\033[93m",
    "production": "\033[95m"
}
BASIC_QUERY_FUNCTIONS = {
    "non_semantic": get_basic_query,
    "elser_eis": get_basic_query,
    "bedrock_titan": get_basic_knn_query
}
BASIC_QUERY_FIELDS = {
    "non_semantic": ["query.title", "query.description"],
    "elser_eis": ["query.titleSemantic", "query.descriptionSemantic"],
    "bedrock_titan": ["query.titleSemantic", "query.descriptionSemantic"]
}
QUERY_TYPES = {
    "non_semantic": "basic",
    "elser_eis": "basic",
    "bedrock_titan": "basic",
    "production": "full"
}

# %%
def get_combined_query_results(query: str):
    results = {}
    for index in INDEXES.keys():
        body = {"size": SIZE, "track_total_hits": True}

        if QUERY_TYPES[index] == "basic":
            body["query"] = BASIC_QUERY_FUNCTIONS[index](query, BASIC_QUERY_FIELDS[index])
        else:
            body["query"] = get_full_query(query)

        response = dict(ES_CLIENT.search(index=INDEXES[index], body=body))
        results[index] = response
    
        hits = response["hits"]["hits"]
        results[index]["ranking"] = {hit["_id"]: i + 1 for i, hit in enumerate(hits)}
        results[index]["ids"] = set(hit["_id"] for hit in hits)

    return results

def compare_query_results(query: str):
    print(f"{BOLD}Query:{RESET} {query}")
    query_terms = query.split(" ")

    results = get_combined_query_results(query)
    print(f"{BOLD}Total results:{RESET}", end=" ")
    for index in INDEXES.keys():
        print(f"{INDEX_COLORS[index]}{COMPARISON_LABELS[index]} {results[index]["hits"]["total"]["value"]}{RESET_COLOR}", end=" ")
    print("\n")

    seen = set()
    for i in range(PRINT_LIMIT):
        print(f"{BOLD}————— {i+1} —————{RESET}\n")
        for index in INDEXES.keys():
            hits = results[index]["hits"]["hits"]

            if len(hits) > i:
                hit = hits[i]        
                work_id = hit["_id"]
                if work_id not in seen:
                    seen.add(work_id)
                    print(get_work_url(work_id))
                    print_bold(highlight_terms(hit["_source"]["display"]["title"], query_terms))
                    if "description" in hit["_source"]["display"]:
                        print(highlight_terms(hit["_source"]["display"]["description"], query_terms))
        
                    for index_2 in INDEXES.keys():
                        print(f"{INDEX_COLORS[index_2]}{COMPARISON_LABELS[index_2]} {results[index_2]["ranking"].get(work_id, "-")}{RESET_COLOR}", end=" ")
        
                    print("\n")

def find_needle_in_haystack(query: str, work_id: str):
    results = {}
    for index in INDEXES.keys():
        body = {"size": 10_000, "track_total_hits": True, "_source": False}

        if QUERY_TYPES[index] == "basic":
            body["query"] = BASIC_QUERY_FUNCTIONS[index](query, BASIC_QUERY_FIELDS[index])
        else:
            body["query"] = get_full_query(query)

        response = dict(ES_CLIENT.search(index=INDEXES[index], body=body))
        results[index] = response
    
        ids = [h["_id"] for h in response["hits"]["hits"]]
                
        if work_id in ids:
            print(f"{INDEX_COLORS[index]}{COMPARISON_LABELS[index]} {ids.index(work_id) + 1}{RESET_COLOR}", end=" ")
        else:
            print(f"{INDEX_COLORS[index]}{COMPARISON_LABELS[index]} -{RESET_COLOR}", end=" ")

# %%
# QUERY = "surgery knife"
# QUERY = "HIV"
# QUERY = "violent criminal"
# QUERY = "lung neoplasm"
#QUERY = "lung neoplasm inflammation"
QUERY = "cardiac failure"
QUERY = "edo japan"
compare_query_results(QUERY)
# Out:
# Query: edo japan
# Total results: ELSER 24206 Titan 573 Control 261 Production 0
#
# ————— 1 —————
#
# https://wellcomecollection.org/works/dqcsv9tp
# "Japan 1"
# Reference file of publications relating to Japan, including a brochure for University of Birmingham Japan Centre, brochures for Japanese buildings, an issue of the British Council's <i>Creative Industries Magazine</i> and a British Chamber of Commerce Japan Fact File.
# ELSER 1 Titan 14 Control 2 Production -
#
# https://wellcomecollection.org/works/jqeq5cp9
# Japan
# Various items of correspondence, particularly with Tanabe Seiyaku Co Ltd, and some notes of meetings.  Correspondence concerning the supply of Newcastle Disease Vaccine.
# ELSER 38 Titan 1 Control 35 Production -
#
# https://wellcomecollection.org/works/sbz6qqth
# "Japan"
# "Japan" by F W Cottam - "discussions in Japan ... and subsequent discussions in Beirut with Mr J H P Upton".  Visited 15-18 March, 1968.  Report number 28/68.
# ELSER 2 Titan 37 Control 1 Production -
#
# ————— 2 —————
#
# https://wellcomecollection.org/works/zzn6puf5
# Japan
# Prospectus for the International Christian University Tokyo, 1980-1982, with order of service listing Browne as preacher, 1981 (in English and Japanese). (Found with H.3/2).
# <p>See also H.5 and H.6</p>
# ELSER 24 Titan 2 Control 34 Production -
#
# ————— 3 —————
#
# https://wellcomecollection.org/works/kn72hpy7
# "Japan 3"
# Correspondence and papers regarding Peter Senior's visit to Japan in February 2000 as part of a British Council Creative Industries Trade Mission, correspondence regarding ideas for potential collaboration between Arts For Health and its Japanese counterparts, brochures regarding various Japanese art events and a sub-folder entitled "Japan Architects CUBE: Sep 2001" containing correspondence and papers regarding a symposium on healthcare architecture in Japan held in Manchester with a Japanese delegation in attendance. Related files are in ART/AFH/A/10/2-4 and ART/AFH/A/10/6-8.
# ELSER 3 Titan - Control 5 Production -
#
# https://wellcomecollection.org/works/t2s776wb
# Japan
# Includes text of RRM's lecture Remarks on Anaesthetics, Nagoya, Mar 1967; photographs of RRM in Japan 1967; Dr I Wakai; award of Honorary Membership of Japanese Society of Anaesthetists.
# ELSER 6 Titan 3 Control 9 Production -
#
# https://wellcomecollection.org/works/cy2b7432
# Japan - correspondence
# <p>Lowenfeld correspondence with:</p>
# <p>Stuart Griffin, c/o Foreign Correspondents Club of Japan, 14 Marunouchi, 2 Chome, Chiyoda-Ku, Tokyo, Japan 1967-1968</p>
# <p>Fusao Kawai, School of Medicine and Mental Disorders, Tenri University, Tokyo, Japan 1967 (3 typed copies)</p>
# <p>David Clark, International House of Japan, 11-16 5 Chome, Roppongi, Minato-Ku, Tokyo, Japan, 1968 (2 letters)</p>
# ELSER 8 Titan 5 Control 3 Production -
#
# ————— 4 —————
#
# https://wellcomecollection.org/works/bwrumnvz
# "Japan 2"
# Correspondence and papers regarding a Japanese delegation visit to CHARTS'99 (Art For Health's Culture, Health, the Arts World Symposium), correspondence regarding Peter Senior's visit to Japan in February 2000,  a copy of the Japan Society of Healing Environment's journal vol.2 no.1 1997 (in Japanese) and volumes 8 and 9 of the magazine <i>Public Art</i> (in Japanese). Related files are in ART/AFH/A/10/2-3 and ART/AFH/A/10/5-8.
# ELSER 4 Titan 16 Control 12 Production -
#
# https://wellcomecollection.org/works/rs9d77h7
# Japan
# One leaflet (with annotations), 1966 and one booklet (produced by Nippon Wellcome K.K), 1982.
# <p>
# Also collection of cuttings and maps entitled 'General Information on the Principle Towns of China, Japan, F.M.S., and Manila, P.I'.  Prepared by Burroughs Wellcome & Co employee, 1924.</p>
# ELSER 15 Titan 4 Control 15 Production -
#
# https://wellcomecollection.org/works/wmek9wpu
# Japan; Hong Kong; Thailand
# Correspondence and papers relating to XXIII International Congress of Physiological Sciences, September 1965, Tokyo, Japan; and Child Health in Japan, November 1965, Tokyo, Japan;<p></p>
#
# <p>Further travel in Japan, Hong Kong and Thailand.</p>
# ELSER 54 Titan - Control 4 Production -
#
# ————— 5 —————
#
# https://wellcomecollection.org/works/szqjmc5m
# M0004133:Four ivory Netsuke, Japan
# Photograph of four netsuke from Doctor Hermann Gunther's collection of Netsuke. Netsuke are ornaments worn with a Kimono. The Netsuke is tied a silk bag hidden behind the sash for belongings. They were especially popular during the Tokugawa period (1603–1868) and are seen by many as fine works of miniature art. The four Netsuke are shaped like a human figure, a Shoki bearing his right shin, a blind man and a man  with a staff. Two of the original objects can be found at the History of Science Museum under the inventory numbers <a href="https://hsm.ox.ac.uk/collections-online#/item/hsm-catalogue-4835" rel="nofollow">50495</a> and <a href="https://hsm.ox.ac.uk/collections-online#/item/hsm-catalogue-4858" rel="nofollow">54541</a>
# ELSER 5 Titan - Control 100 Production -
#
# ————— 6 —————
#
# https://wellcomecollection.org/works/nb5k622p
# "Notes for Tokyo paper on development of GA in GB"
# Includes letter from Yujiro Isoda.
# ELSER 59 Titan 6 Control - Production -
#
# https://wellcomecollection.org/works/tehum6ub
# Japan, 1966
# Material relating to Hart's attendance at a conference on tuberculosis organised by the United States.-Japan Cooperative Medical Science Programme, held in Japan in May 1966. Includes correspondence with colleagues and notebook containing cursory notes and lists regarding travel arrangements, contact details and expenses.
# ELSER 31 Titan 11 Control 6 Production -
#
# ————— 7 —————
#
# https://wellcomecollection.org/works/v6yp85nv
# Japan
# Human rights and Japanese mental hospitals. Includes visits by International Commission of Jurists, WHO reports, and WFMH monitoring
# ELSER 7 Titan 30 Control 32 Production -
#
# https://wellcomecollection.org/works/cc9veem5
# "Japan - Yoko"
# Correspondence and papers regarding the Healthcare Architecture in Japan Symposium held 27-28 September 2001 in Manchester, along with correspondence with Yoko Hayashi regarding setting up an Arts For Health type organisation Japan. Related files are in ART/AFH/A/10/2-7.
# ELSER 13 Titan 7 Control 8 Production -
#
# https://wellcomecollection.org/works/uty2kwtd
# Japan 1993
# Proceedings of the 1993 WFMH World Congress, in Makuhari, Chiba, Japan in August 1993 (publication)..
# ELSER 29 Titan - Control 7 Production -
#
# ————— 8 —————
#
# https://wellcomecollection.org/works/k73ja4m9
# Japan: miscellaneous correspondents
# Correspondents include: Yurika Ayukawa, Citizens' Nuclear Information Centre; Keiko Nakagawa; Yasuo Nakagawa; Prof Yoshiyuki Hanawa; Manami Suzuki, Japan Congress against A- and H-Bombs; Jungi Sakurai; Dr T Yamada; Dr Yowri Ujeno; Dr Kenji Takeshita; Dr Naomi Shomo; Prof Tamaki Kono
# ELSER 23 Titan 8 Control 18 Production -
#
# ————— 9 —————
#
# https://wellcomecollection.org/works/u9c94988
# Art, Culture and Hospital Design in Japan
# A recording of a conference / seminar in Japan.<p></p>
# ELSER 9 Titan 12 Control 10 Production -
#
# https://wellcomecollection.org/works/fqkrpdf3
# Kyoto Imperial University
# Contains a letter from Taku Komai, Kyoto Imperial University, enclosing statistics of insanity in Japan, and a reply from L S Penrose thanking him for the information.
# ELSER 39 Titan 9 Control - Production -
#
# ————— 10 —————
#
# https://wellcomecollection.org/works/q88z42ne
# M0004135: Four ivory Netsuke, Japan
# Photograph of four netsuke from Doctor Hermann Gunther's collection of Netsuke. Netsuke are ornaments worn with a Kimono. The Netsuke is tied a silk bag hidden behind the sash for belongings. They were especially popular during the Tokugawa period (1603–1868) and are seen by many as fine works of miniature art. The four Netsuke are shaped like a blind Amma wearing a Hakama and carrying a sack, four blind men fighting, a naked blind man lifting a stone and a blind man crawling along a rope bridge. The original objects can be found at the History of Science Museum under the inventory numbers <a href="https://hsm.ox.ac.uk/collections-online#/item/hsm-catalogue-4832" rel="nofollow">36569</a>, <a href="https://hsm.ox.ac.uk/collections-online#/item/hsm-catalogue-4821" rel="nofollow">33845</a> and <a href="https://hsm.ox.ac.uk/collections-online#/item/hsm-catalogue-4869" rel="nofollow">43975</a> and <a href="https://hsm.ox.ac.uk/collections-online#/item/hsm-catalogue-4837" rel="nofollow">52754</a>
# ELSER 10 Titan - Control 80 Production -
#
# https://wellcomecollection.org/works/errkrutz
# Japan: Inada - Itagaki
# <p>1 Ryukichi Inada, in France 1924</p>
# <p>2 Makoto Ishihara (in German), in Edinburgh 1923</p>
# <p>3-12 Masamitsu Itagaki, Kyushi Imperial University, Fukuokal 1914-1930</p>
# ELSER 30 Titan 10 Control 67 Production -

# %%
find_needle_in_haystack("lung neoplasm", "s3e28zhn")
# Out:
# ELSER 377 Titan 59 Control - Production 1

# %%
find_needle_in_haystack("cardiac failure", "e37qcyfm")
# Out:
# ELSER 7 Titan 1 Control 60 Production -
